# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
steam = pd.read_csv("clean_data/steam_for_model.csv")

# %%
steam.head()
# Out:
#     appid                              name release_date  \
# 0     730  Counter-Strike: Global Offensive   2012-08-21
# 1     570                            Dota 2   2013-07-09
# 2  578080     PLAYERUNKNOWN'S BATTLEGROUNDS   2017-12-21
# 3     440                   Team Fortress 2   2007-10-10
# 4  271590                Grand Theft Auto V   2015-04-13
#
#                          developer         publisher  free_to_play  \
# 0  Valve;Hidden Path Entertainment             Valve          True
# 1                            Valve             Valve          True
# 2                 PUBG Corporation  PUBG Corporation         False
# 3                            Valve             Valve          True
# 4                   Rockstar North    Rockstar Games         False
#
#    virtual_reality_support controller_support  steam_workshop  singleplayer  \
# 0                    False               Full            True         False
# 1                    False                 No            True         False
# 2                    False                 No           False         False
# 3                    False                 No            True         False
# 4                    False               Full           False          True
#
#    ...  achievements   general_rating  positive_ratings  negative_ratings  \
# 0  ...           167         Positive           2644404            402313
# 1  ...             0         Positive            863507            142079
# 2  ...            37            Mixed            496184            487076
# 3  ...           520         Positive            515879             34036
# 4  ...            77  Mostly Positive            329061            139308
#
#    average_playtime  median_playtime        owners  price  total_reviews  \
# 0             22494             6502   50M to 100M   0.00        3046717
# 1             23944              801  100M to 200M   0.00        1005586
# 2             22938            12434   50M to 100M  26.99         983260
# 3              8495              623    20M to 50M   0.00         549915
# 4              9837             4834    10M to 20M  24.99         468369
#
#    is_indie
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#
# [5 rows x 39 columns]

# %%
steam.corr()
# Out:
#                             appid  free_to_play  virtual_reality_support  \
# appid                    1.000000      0.044071                 0.071224
# free_to_play             0.044071      1.000000                 0.023786
# virtual_reality_support  0.071224      0.023786                 1.000000
# steam_workshop          -0.093728     -0.011300                -0.034562
# singleplayer            -0.007595     -0.234156                -0.004280
# multiplayer             -0.137124      0.140699                -0.040482
# is_open_world           -0.098362     -0.010561                -0.021596
# is_rogue_like           -0.042567     -0.011396                -0.013681
# is_metroidvania         -0.018349     -0.008688                -0.011916
# is_visual_novel         -0.010503      0.012276                -0.036417
# has_great_soundtrack    -0.043521     -0.013154                -0.012935
# is_shooter              -0.145093      0.001811                -0.026720
# is_rpg                  -0.057145      0.007405                -0.063330
# has_female_protagonist  -0.062524     -0.019057                -0.020603
# is_sports               -0.006822     -0.009962                 0.069850
# is_simulation            0.003174     -0.030228                 0.088941
# windows_support          0.000910     -0.007604                 0.003557
# mac_support             -0.143171     -0.005544                -0.163698
# linux_support           -0.142714     -0.025074                -0.122704
# is_positive             -0.219517      0.073940                -0.032359
# required_age            -0.089262     -0.009551                -0.019714
# achievements             0.042704     -0.014252                -0.026471
# positive_ratings        -0.071023      0.046370                -0.012467
# negative_ratings        -0.052141      0.042089                -0.011789
# average_playtime        -0.072023      0.068745                -0.019898
# median_playtime         -0.050460      0.050221                -0.014975
# price                   -0.149852     -0.199098                 0.003048
# total_reviews           -0.070090      0.047298                -0.012807
# is_indie                 0.208003     -0.143973                -0.077113
#
#                          steam_workshop  singleplayer  multiplayer  \
# appid                         -0.093728     -0.007595    -0.137124
# free_to_play                  -0.011300     -0.234156     0.140699
# virtual_reality_support       -0.034562     -0.004280    -0.040482
# steam_workshop                 1.000000     -0.040901     0.102778
# singleplayer                  -0.040901      1.000000    -0.345381
# multiplayer                    0.102778     -0.345381     1.000000
# is_open_world                  0.037113     -0.024368     0.064951
# is_rogue_like                  0.025358      0.014515    -0.006360
# is_metroidvania                0.005101      0.010693    -0.016212
# is_visual_novel               -0.026184      0.031442    -0.073896
# has_great_soundtrack           0.002908      0.015738    -0.020661
# is_shooter                     0.035257     -0.055739     0.113395
# is_rpg                        -0.011939      0.003378    -0.041339
# has_female_protagonist        -0.006370      0.020110    -0.036953
# is_sports                      0.013478     -0.003087     0.136743
# is_simulation                  0.057892      0.060986    -0.024918
# windows_support                0.002558     -0.003192     0.000558
# mac_support                    0.069558      0.021423     0.008606
# linux_support                  0.096165      0.023134     0.016366
# is_positive                    0.130460     -0.045914     0.126202
# required_age                   0.006819      0.010935     0.023218
# achievements                   0.000131      0.017788    -0.029006
# positive_ratings               0.093455     -0.054510     0.055294
# negative_ratings               0.059309     -0.070335     0.061460
# average_playtime               0.049450     -0.039948     0.048208
# median_playtime                0.026860     -0.027436     0.030721
# price                          0.105163      0.006603     0.124884
# total_reviews                  0.090451     -0.059586     0.058554
# is_indie                      -0.053229      0.106855    -0.141176
#
#                          is_open_world  is_rogue_like  is_metroidvania  \
# appid                        -0.098362      -0.042567        -0.018349
# free_to_play                 -0.010561      -0.011396        -0.008688
# virtual_reality_support      -0.021596      -0.013681        -0.011916
# steam_workshop                0.037113       0.025358         0.005101
# singleplayer                 -0.024368       0.014515         0.010693
# multiplayer                   0.064951      -0.006360        -0.016212
# is_open_world                 1.000000      -0.005982        -0.004407
# is_rogue_like                -0.005982       1.000000         0.010339
# is_metroidvania              -0.004407       0.010339         1.000000
# is_visual_novel              -0.013469      -0.008764        -0.006456
# has_great_soundtrack         -0.006486       0.004775         0.021269
# is_shooter                    0.012228       0.015088        -0.006963
# is_rpg                        0.024337       0.075495        -0.007253
# has_female_protagonist       -0.003670      -0.005393         0.053425
# is_sports                    -0.014305      -0.010837        -0.007984
# is_simulation                -0.012639      -0.023213        -0.017101
# windows_support               0.001316       0.000856         0.000631
# mac_support                  -0.019883       0.040794         0.018057
# linux_support                -0.013491       0.059116         0.026862
# is_positive                   0.178903       0.038215         0.042557
# required_age                  0.133583      -0.005195        -0.001339
# achievements                 -0.004516       0.002410        -0.002217
# positive_ratings              0.070134       0.009177         0.002804
# negative_ratings              0.085813       0.000912        -0.000417
# average_playtime              0.067445       0.012068         0.001075
# median_playtime               0.041517       0.009656         0.001724
# price                         0.125060       0.010406         0.020616
# total_reviews                 0.075770       0.007943         0.002294
# is_indie                     -0.115418      -0.001204        -0.006193
#
#                          is_visual_novel  ...  is_positive  required_age  \
# appid                          -0.010503  ...    -0.219517     -0.089262
# free_to_play                    0.012276  ...     0.073940     -0.009551
# virtual_reality_support        -0.036417  ...    -0.032359     -0.019714
# steam_workshop                 -0.026184  ...     0.130460      0.006819
# singleplayer                    0.031442  ...    -0.045914      0.010935
# multiplayer                    -0.073896  ...     0.126202      0.023218
# is_open_world                  -0.013469  ...     0.178903      0.133583
# is_rogue_like                  -0.008764  ...     0.038215     -0.005195
# is_metroidvania                -0.006456  ...     0.042557     -0.001339
# is_visual_novel                 1.000000  ...    -0.003587      0.040751
# has_great_soundtrack            0.018907  ...     0.078927      0.027613
# is_shooter                     -0.021280  ...     0.120535      0.072824
# is_rpg                         -0.035340  ...     0.028385      0.009633
# has_female_protagonist          0.061119  ...     0.032047      0.044804
# is_sports                      -0.024399  ...    -0.010206     -0.013059
# is_simulation                  -0.033029  ...    -0.016943     -0.034173
# windows_support                 0.001927  ...     0.004950     -0.036717
# mac_support                     0.080892  ...     0.078048     -0.029352
# linux_support                   0.105287  ...     0.077251     -0.016350
# is_positive                    -0.003587  ...     1.000000      0.164276
# required_age                    0.040751  ...     0.164276      1.000000
# achievements                   -0.013208  ...    -0.009565     -0.005511
# positive_ratings               -0.002419  ...     0.129928      0.060933
# negative_ratings               -0.005155  ...     0.092765      0.058073
# average_playtime               -0.001147  ...     0.107353      0.035302
# median_playtime                 0.000042  ...     0.062814      0.015366
# price                           0.049440  ...     0.178237      0.122350
# total_reviews                  -0.003033  ...     0.127721      0.062681
# is_indie                       -0.051504  ...    -0.220068     -0.113382
#
#                          achievements  positive_ratings  negative_ratings  \
# appid                        0.042704         -0.071023         -0.052141
# free_to_play                -0.014252          0.046370          0.042089
# virtual_reality_support     -0.026471         -0.012467         -0.011789
# steam_workshop               0.000131          0.093455          0.059309
# singleplayer                 0.017788         -0.054510         -0.070335
# multiplayer                 -0.029006          0.055294          0.061460
# is_open_world               -0.004516          0.070134          0.085813
# is_rogue_like                0.002410          0.009177          0.000912
# is_metroidvania             -0.002217          0.002804         -0.000417
# is_visual_novel             -0.013208         -0.002419         -0.005155
# has_great_soundtrack        -0.003008          0.019742          0.003742
# is_shooter                  -0.006609          0.085438          0.086391
# is_rpg                      -0.003067          0.000257         -0.003465
# has_female_protagonist      -0.006907          0.002940          0.000497
# is_sports                   -0.011853         -0.007161         -0.004367
# is_simulation                0.007970         -0.009549         -0.009117
# windows_support              0.001246          0.000695          0.000600
# mac_support                 -0.024597          0.031510          0.009331
# linux_support               -0.010365          0.040424          0.014948
# is_positive                 -0.009565          0.129928          0.092765
# required_age                -0.005511          0.060933          0.058073
# achievements                 1.000000          0.005966          0.003484
# positive_ratings             0.005966          1.000000          0.762795
# negative_ratings             0.003484          0.762795          1.000000
# average_playtime             0.014256          0.159568          0.162838
# median_playtime              0.010138          0.036367          0.048679
# price                       -0.008241          0.036271          0.051607
# total_reviews                0.005717          0.992340          0.836837
# is_indie                     0.010294         -0.054640         -0.051286
#
#                          average_playtime  median_playtime     price  \
# appid                           -0.072023        -0.050460 -0.149852
# free_to_play                     0.068745         0.050221 -0.199098
# virtual_reality_support         -0.019898        -0.014975  0.003048
# steam_workshop                   0.049450         0.026860  0.105163
# singleplayer                    -0.039948        -0.027436  0.006603
# multiplayer                      0.048208         0.030721  0.124884
# is_open_world                    0.067445         0.041517  0.125060
# is_rogue_like                    0.012068         0.009656  0.010406
# is_metroidvania                  0.001075         0.001724  0.020616
# is_visual_novel                 -0.001147         0.000042  0.049440
# has_great_soundtrack             0.004221         0.003313  0.026734
# is_shooter                       0.020767         0.006913  0.034539
# is_rpg                           0.024638         0.025334  0.052788
# has_female_protagonist           0.003151         0.000757  0.042484
# is_sports                       -0.003710        -0.002369  0.070820
# is_simulation                   -0.005880        -0.005069  0.086318
# windows_support                  0.001127         0.000852  0.002983
# mac_support                      0.028622         0.020618  0.020440
# linux_support                    0.032038         0.021985  0.014341
# is_positive                      0.107353         0.062814  0.178237
# required_age                     0.035302         0.015366  0.122350
# achievements                     0.014256         0.010138 -0.008241
# positive_ratings                 0.159568         0.036367  0.036271
# negative_ratings                 0.162838         0.048679  0.051607
# average_playtime                 1.000000         0.913312  0.049964
# median_playtime                  0.913312         1.000000  0.037585
# price                            0.049964         0.037585  1.000000
# total_reviews                    0.166201         0.040088  0.040567
# is_indie                        -0.061758        -0.041633 -0.230317
#
#                          total_reviews  is_indie
# appid                        -0.070090  0.208003
# free_to_play                  0.047298 -0.143973
# virtual_reality_support      -0.012807 -0.077113
# steam_workshop                0.090451 -0.053229
# singleplayer                 -0.059586  0.106855
# multiplayer                   0.058554 -0.141176
# is_open_world                 0.075770 -0.115418
# is_rogue_like                 0.007943 -0.001204
# is_metroidvania               0.002294 -0.006193
# is_visual_novel              -0.003033 -0.051504
# has_great_soundtrack          0.017429 -0.027182
# is_shooter                    0.088838 -0.097408
# is_rpg                       -0.000445 -0.082808
# has_female_protagonist        0.002584 -0.049770
# is_sports                    -0.006897 -0.089892
# is_simulation                -0.009826 -0.138451
# windows_support               0.000703  0.000047
# mac_support                   0.028459  0.067566
# linux_support                 0.037079  0.088273
# is_positive                   0.127721 -0.220068
# required_age                  0.062681 -0.113382
# achievements                  0.005717  0.010294
# positive_ratings              0.992340 -0.054640
# negative_ratings              0.836837 -0.051286
# average_playtime              0.166201 -0.061758
# median_playtime               0.040088 -0.041633
# price                         0.040567 -0.230317
# total_reviews                 1.000000 -0.056057
# is_indie                     -0.056057  1.000000
#
# [29 rows x 29 columns]

# %%
steam.corr().is_positive.sort_values(ascending = False)
# Out:
# is_positive                1.000000
# is_open_world              0.178903
# price                      0.178237
# required_age               0.164276
# steam_workshop             0.130460
# positive_ratings           0.129928
# total_reviews              0.127721
# multiplayer                0.126202
# is_shooter                 0.120535
# average_playtime           0.107353
# negative_ratings           0.092765
# has_great_soundtrack       0.078927
# mac_support                0.078048
# linux_support              0.077251
# free_to_play               0.073940
# median_playtime            0.062814
# is_metroidvania            0.042557
# is_rogue_like              0.038215
# has_female_protagonist     0.032047
# is_rpg                     0.028385
# windows_support            0.004950
# is_visual_novel           -0.003587
# achievements              -0.009565
# is_sports                 -0.010206
# is_simulation             -0.016943
# virtual_reality_support   -0.032359
# singleplayer              -0.045914
# appid                     -0.219517
# is_indie                  -0.220068
# Name: is_positive, dtype: float64

# %% [markdown]
# number of ratings is probably not worth keeping in this case - Also don't really need stuff like name and release date

# %%
steam_model_base = steam.drop(["appid", "positive_ratings", "negative_ratings", "total_reviews", "general_rating", "name", "release_date",
           "developer", "publisher","categories", "genres", "steamspy_tags", "owners", "average_playtime", "median_playtime", "price", "required_age", "achievements"], axis = "columns").copy()

# %%
steam_model_base
# Out:
#        free_to_play  virtual_reality_support controller_support  \
# 0              True                    False               Full
# 1              True                    False                 No
# 2             False                    False                 No
# 3              True                    False                 No
# 4             False                    False               Full
# ...             ...                      ...                ...
# 26559         False                    False                 No
# 26560         False                    False                 No
# 26561         False                    False                 No
# 26562         False                    False               Full
# 26563         False                    False               Full
#
#        steam_workshop  singleplayer  multiplayer  is_open_world  \
# 0                True         False         True          False
# 1                True         False         True          False
# 2               False         False         True          False
# 3                True         False         True          False
# 4               False          True         True           True
# ...               ...           ...          ...            ...
# 26559           False          True        False          False
# 26560           False          True        False          False
# 26561           False          True        False          False
# 26562           False          True        False          False
# 26563           False          True         True          False
#
#        is_rogue_like  is_metroidvania  is_visual_novel  ...  is_shooter  \
# 0              False            False            False  ...        True
# 1              False            False            False  ...       False
# 2              False            False            False  ...        True
# 3              False            False            False  ...        True
# 4              False            False            False  ...       False
# ...              ...              ...              ...  ...         ...
# 26559          False            False            False  ...       False
# 26560          False            False            False  ...       False
# 26561          False            False            False  ...       False
# 26562          False            False            False  ...       False
# 26563          False            False            False  ...       False
#
#        is_rpg  has_female_protagonist  is_sports  is_simulation  \
# 0       False                   False      False          False
# 1       False                   False      False          False
# 2       False                   False      False          False
# 3       False                   False      False          False
# 4       False                   False      False          False
# ...       ...                     ...        ...            ...
# 26559   False                   False      False          False
# 26560   False                   False      False          False
# 26561   False                   False      False          False
# 26562   False                   False      False          False
# 26563   False                   False      False          False
#
#        windows_support  mac_support  linux_support  is_positive  is_indie
# 0                 True         True           True         True     False
# 1                 True         True           True         True     False
# 2                 True        False          False        False     False
# 3                 True         True           True         True     False
# 4                 True        False          False         True     False
# ...                ...          ...            ...          ...       ...
# 26559             True        False          False         True      True
# 26560             True        False          False        False      True
# 26561             True        False          False         True      True
# 26562             True        False          False        False      True
# 26563             True        False          False         True      True
#
# [26564 rows x 21 columns]

# %%
steam_model_base = pd.get_dummies(steam_model_base, drop_first = True)

# %%
model_pred = steam_model_base.drop(columns = "is_positive").copy()

# %%
model_resp = steam_model_base["is_positive"].copy()

# %%
model_pred
# Out:
#        free_to_play  virtual_reality_support  steam_workshop  singleplayer  \
# 0              True                    False            True         False
# 1              True                    False            True         False
# 2             False                    False           False         False
# 3              True                    False            True         False
# 4             False                    False           False          True
# ...             ...                      ...             ...           ...
# 26559         False                    False           False          True
# 26560         False                    False           False          True
# 26561         False                    False           False          True
# 26562         False                    False           False          True
# 26563         False                    False           False          True
#
#        multiplayer  is_open_world  is_rogue_like  is_metroidvania  \
# 0             True          False          False            False
# 1             True          False          False            False
# 2             True          False          False            False
# 3             True          False          False            False
# 4             True           True          False            False
# ...            ...            ...            ...              ...
# 26559        False          False          False            False
# 26560        False          False          False            False
# 26561        False          False          False            False
# 26562        False          False          False            False
# 26563         True          False          False            False
#
#        is_visual_novel  has_great_soundtrack  is_shooter  is_rpg  \
# 0                False                 False        True   False
# 1                False                 False       False   False
# 2                False                 False        True   False
# 3                False                 False        True   False
# 4                False                 False       False   False
# ...                ...                   ...         ...     ...
# 26559            False                 False       False   False
# 26560            False                 False       False   False
# 26561            False                 False       False   False
# 26562            False                 False       False   False
# 26563            False                 False       False   False
#
#        has_female_protagonist  is_sports  is_simulation  windows_support  \
# 0                       False      False          False             True
# 1                       False      False          False             True
# 2                       False      False          False             True
# 3                       False      False          False             True
# 4                       False      False          False             True
# ...                       ...        ...            ...              ...
# 26559                   False      False          False             True
# 26560                   False      False          False             True
# 26561                   False      False          False             True
# 26562                   False      False          False             True
# 26563                   False      False          False             True
#
#        mac_support  linux_support  is_indie  controller_support_No
# 0             True           True     False                      0
# 1             True           True     False                      1
# 2            False          False     False                      1
# 3             True           True     False                      1
# 4            False          False     False                      0
# ...            ...            ...       ...                    ...
# 26559        False          False      True                      1
# 26560        False          False      True                      1
# 26561        False          False      True                      1
# 26562        False          False      True                      0
# 26563        False          False      True                      0
#
# [26564 rows x 20 columns]

# %%
model_resp
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 26559     True
# 26560    False
# 26561     True
# 26562    False
# 26563     True
# Name: is_positive, Length: 26564, dtype: bool

# %%
steam_pred_train, steam_pred_test, steam_resp_train, steam_resp_test = (
    train_test_split(
        model_pred,
        model_resp,
        test_size = 0.2
    )
)

# %% [markdown]
# ## Building the random forest

# %%
model_forest = RandomForestClassifier(n_estimators = 500)

# %%
model_forest.fit(steam_pred_train, steam_resp_train)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
scores_forest = cross_val_score(model_forest, steam_pred_train, steam_resp_train, scoring = "accuracy", cv = 10)

# %%
scores_forest
# Out:
# array([0.89087488, 0.89129412, 0.89129412, 0.89458824, 0.896     ,
#        0.89458824, 0.88847059, 0.89035294, 0.88894118, 0.896     ])

# %%
np.mean(scores_forest)
# Out:
# 0.8922404294172985

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

steam_pred_names = list(steam_pred_test)
steam_resp_names = ["0", "1"]

# %%
fig = plt.figure(figsize=(12, 12))

# %%
plot_tree(model_forest.estimators_[0], # Pull out one tree from the forest
          max_depth = 2, 
          feature_names = steam_pred_names,
          class_names = steam_resp_names, 
          filled=True,
         fontsize = 4);

# %%
# Get numerical feature importances
importances = list(model_forest.feature_importances_)

# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(steam_pred_names, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:40} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: is_indie                                 Importance: 0.23
# Variable: is_open_world                            Importance: 0.12
# Variable: steam_workshop                           Importance: 0.08
# Variable: multiplayer                              Importance: 0.07
# Variable: controller_support_No                    Importance: 0.07
# Variable: is_shooter                               Importance: 0.06
# Variable: mac_support                              Importance: 0.06
# Variable: linux_support                            Importance: 0.05
# Variable: free_to_play                             Importance: 0.04
# Variable: is_rpg                                   Importance: 0.04
# Variable: singleplayer                             Importance: 0.03
# Variable: has_great_soundtrack                     Importance: 0.03
# Variable: is_simulation                            Importance: 0.03
# Variable: virtual_reality_support                  Importance: 0.02
# Variable: is_rogue_like                            Importance: 0.02
# Variable: is_sports                                Importance: 0.02
# Variable: is_metroidvania                          Importance: 0.01
# Variable: is_visual_novel                          Importance: 0.01
# Variable: has_female_protagonist                   Importance: 0.01
# Variable: windows_support                          Importance: 0.0

# %% [markdown]
# ## If we adjust the threshold to be "positive or better", how does the decision tree change?

# %%
steam_2 = steam = pd.read_csv("clean_data/harsher_steam_for_model.csv")

# %%
steam_model_base_2 = steam_2.drop(["appid", "positive_ratings", "negative_ratings", "total_reviews", "general_rating", "name", "release_date",
           "developer", "publisher","categories", "genres", "steamspy_tags", "owners", "average_playtime", "median_playtime", "price", "required_age", "achievements", "is_indie"], axis = "columns").copy()

# %%
steam_model_base_2 = pd.get_dummies(steam_model_base_2, drop_first = True)

# %%
steam_model_base_2
# Out:
#        free_to_play  virtual_reality_support  steam_workshop  singleplayer  \
# 0              True                    False            True         False
# 1              True                    False            True         False
# 2             False                    False           False         False
# 3              True                    False            True         False
# 4             False                    False           False          True
# ...             ...                      ...             ...           ...
# 26559         False                    False           False          True
# 26560         False                    False           False          True
# 26561         False                    False           False          True
# 26562         False                    False           False          True
# 26563         False                    False           False          True
#
#        multiplayer  is_open_world  is_rogue_like  is_metroidvania  \
# 0             True          False          False            False
# 1             True          False          False            False
# 2             True          False          False            False
# 3             True          False          False            False
# 4             True           True          False            False
# ...            ...            ...            ...              ...
# 26559        False          False          False            False
# 26560        False          False          False            False
# 26561        False          False          False            False
# 26562        False          False          False            False
# 26563         True          False          False            False
#
#        is_visual_novel  has_great_soundtrack  is_shooter  is_rpg  \
# 0                False                 False        True   False
# 1                False                 False       False   False
# 2                False                 False        True   False
# 3                False                 False        True   False
# 4                False                 False       False   False
# ...                ...                   ...         ...     ...
# 26559            False                 False       False   False
# 26560            False                 False       False   False
# 26561            False                 False       False   False
# 26562            False                 False       False   False
# 26563            False                 False       False   False
#
#        has_female_protagonist  is_sports  is_simulation  windows_support  \
# 0                       False      False          False             True
# 1                       False      False          False             True
# 2                       False      False          False             True
# 3                       False      False          False             True
# 4                       False      False          False             True
# ...                       ...        ...            ...              ...
# 26559                   False      False          False             True
# 26560                   False      False          False             True
# 26561                   False      False          False             True
# 26562                   False      False          False             True
# 26563                   False      False          False             True
#
#        mac_support  linux_support  is_positive  controller_support_No
# 0             True           True         True                      0
# 1             True           True         True                      1
# 2            False          False        False                      1
# 3             True           True         True                      1
# 4            False          False        False                      0
# ...            ...            ...          ...                    ...
# 26559        False          False        False                      1
# 26560        False          False        False                      1
# 26561        False          False        False                      1
# 26562        False          False        False                      0
# 26563        False          False        False                      0
#
# [26564 rows x 20 columns]

# %%
model_pred_2 = steam_model_base_2.drop(columns = "is_positive").copy()

# %%
model_resp_2 = steam_model_base_2["is_positive"].copy()

# %%
harsh_pred_train, harsh_pred_test, harsh_resp_train, harsh_resp_test = (
    train_test_split(
        model_pred_2,
        model_resp_2,
        test_size = 0.2
    )
)

# %%
model_harsh = RandomForestClassifier(n_estimators = 1000)

# %%
model_harsh.fit(harsh_pred_train, harsh_resp_train)
# Out:
# RandomForestClassifier(n_estimators=1000)

# %%
scores_harsh = cross_val_score(model_harsh, harsh_pred_train, harsh_resp_train, scoring = "accuracy", cv = 15)

# %%
scores_harsh
# Out:
# array([0.92731122, 0.92801694, 0.9308398 , 0.93013409, 0.93013409,
#        0.93436838, 0.9308398 , 0.92942837, 0.93013409, 0.9308398 ,
#        0.92731122, 0.93432203, 0.93079096, 0.93079096, 0.9329096 ])

# %%
harsh_pred_names = list(harsh_pred_test)
harsh_resp_names = ["0", "1"]

# %%
# Get numerical feature importances
importances = list(model_harsh.feature_importances_)

# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(harsh_pred_names, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:40} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: steam_workshop                           Importance: 0.12
# Variable: is_open_world                            Importance: 0.11
# Variable: is_shooter                               Importance: 0.1
# Variable: multiplayer                              Importance: 0.08
# Variable: mac_support                              Importance: 0.08
# Variable: linux_support                            Importance: 0.08
# Variable: controller_support_No                    Importance: 0.08
# Variable: free_to_play                             Importance: 0.05
# Variable: has_great_soundtrack                     Importance: 0.05
# Variable: is_rpg                                   Importance: 0.05
# Variable: singleplayer                             Importance: 0.04
# Variable: is_simulation                            Importance: 0.04
# Variable: is_rogue_like                            Importance: 0.03
# Variable: is_metroidvania                          Importance: 0.02
# Variable: is_visual_novel                          Importance: 0.02
# Variable: has_female_protagonist                   Importance: 0.02
# Variable: is_sports                                Importance: 0.02
# Variable: virtual_reality_support                  Importance: 0.01
# Variable: windows_support                          Importance: 0.0
